# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Part-1: Data Exploration and Pre-processing

# %% [markdown]
# # 1) load dataset

# %%
data = pd.read_csv(r"D:\ml-project\1768299091977-ML Linear Regression Home Price Prediction & Analysis Project  Resource16932049360.txt")

# %%
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %% [markdown]
# # 2) Print all the column names

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# # 3) Describe the data

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %% [markdown]
# # 4) Drop address, date, postcode, YearBuilt, lattitude, longtitude columns

# %%
data.drop(["Address","Date","Postcode","YearBuilt","Lattitude","Longtitude"],axis=1,inplace=True)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %% [markdown]
# # 5) Find the count of null value in each column

# %%
data.isnull().any()
# Out:
# Suburb           False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Distance          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# CouncilArea       True
# Regionname        True
# Propertycount     True
# dtype: bool

# %% [markdown]
# # 6) Fill the null value of property count, distance, Bedroom2, Bathroom, Car with 0

# %%
data[["Propertycount","Distance","Bedroom2","Bathroom","Car"]]=data[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].fillna(0)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %% [markdown]
# # 7) Fill Null value of land size and bidding area columns with Mean

# %%
m=data[["Landsize","BuildingArea"]].mean()
m
# Out:
# Landsize        593.598993
# BuildingArea    160.256400
# dtype: float64

# %%
data[["Landsize","BuildingArea"]]=data[["Landsize","BuildingArea"]].fillna(m)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %% [markdown]
# # 8) Find the unique value in method column

# %%
data["Method"].unique()
# Out:
# array(['SS', 'S', 'VB', 'SP', 'PI', 'SN', 'W', 'PN', 'SA'], dtype=object)

# %% [markdown]
# # 9) Create a dummy data for categorical data

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
print(data.isnull().sum())
# Out:
# Rooms                                    0
# Price                                    0
# Distance                                 0
# Bedroom2                                 0
# Bathroom                                 0
#                                         ..
# Regionname_Northern Victoria             0
# Regionname_South-Eastern Metropolitan    0
# Regionname_Southern Metropolitan         0
# Regionname_Western Metropolitan          0
# Regionname_Western Victoria              0
# Length: 795, dtype: int64

# %%
data = data.dropna(subset=['Price'])

# %% [markdown]
# # Part-2: Working with Model

# %% [markdown]
# # 1) Create the target data and feature data where target data is price

# %%
x=data.drop("Price",axis=1)
y=data["Price"]

# %%
x=x.fillna(0)
y=y.fillna(0)

# %%
from sklearn.model_selection import train_test_split

# %%
# split data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # 2) Create a linear regression model for Target and feature data

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction
ypri=lr.predict(x_test)

# %% [markdown]
# # 3) Check if the model is overfitting or underfitting or it is accurate

# %%
train_score=lr.score(x_train,y_train)
test_score=lr.score(x_test,y_test)
print ("train score :" ,train_score)
print("test score : ",test_score)
# Out:
# train score : 0.6848643213384157
# test score :  -14123426579.175844

# %% [markdown]
# # 4) If the model is overfitting then apply ridge and lasso regression algorithms

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(x_train, y_train)
# Out:
# Ridge()

# %%
lasso = Lasso(alpha=0.1)
lasso.fit(x_train, y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.400e+15, tolerance: 8.882e+11
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1)

# %% [markdown]
# # model is underfitting that's why i use decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Create model
dt = DecisionTreeRegressor(max_depth=5, random_state=42)

# Train model
dt.fit(x_train, y_train)

# Prediction
y_pred_dt = dt.predict(x_test)

# Scores
train_score = dt.score(x_train, y_train)
test_score = dt.score(x_test, y_test)

print("Train Score:", train_score)
print("Test Score:", test_score)
# Out:
# Train Score: 0.6226208787239017
# Test Score: 0.5950356192547761

# %% [markdown]
# # 5) Extract slope and intercept value from the model

# %%
# Intercept (c)
print("Intercept:", lr.intercept_)

# Slopes (m values for each feature)
print("Coefficients:", lr.coef_)
# Out:
# Intercept: -1440602040272.1348
# Coefficients: [ 2.63925573e+05 -4.63978288e+04 -8.51983932e+04  1.30454822e+05
#   4.18859265e+04  8.56571943e+00  3.62302316e+01 -4.64919709e+08
#   5.44519609e+11  1.43763009e+12 -7.62718078e+11 -7.58003927e+12
#  -6.29750864e+11 -1.56554828e+12  2.05585421e+12  3.13865194e+12
#   1.97728246e+12 -1.05003845e+12 -1.56839346e+12  2.88027589e+12
#  -1.28754642e+12 -2.28508976e+12 -2.35345562e+11 -5.05464206e+11
#   4.05410868e+11  1.92021656e+12 -9.17404342e+10 -6.70433975e+11
#  -7.73253332e+12 -6.48073264e+10  9.24076699e+11  1.63072534e+12
#  -2.22282821e+12 -1.43596416e+12 -2.06779021e+12  1.28577278e+12
#  -2.13258558e+11  1.80788908e+12  2.39733795e+12  4.33791271e+12
#   1.02455549e+13  1.23473524e+11  1.85097958e+12  5.27817819e+11
#   1.23449580e+12 -2.06055457e+11  3.80376015e+12 -8.10358563e+10
#   1.33584857e+12 -4.10242685e+11  2.08684110e+12  3.70939937e+12
#   2.01662627e+12  1.87641685e+12 -1.70927771e+12 -1.19834768e+12
# ...

# %% [markdown]
# # 6) Display Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(y_test, ypri)
print("MSE:", mse)
# Out:
# MSE: 6.035077219175454e+21

# %% [markdown]
# # 7) Display Mean Absolute Error

# %%
mae = mean_absolute_error(y_test, ypri)
print("MAE:", mae)
# Out:
# MAE: 2728602058.866733

# %% [markdown]
# # 8) Display Root mean Squared error

# %%
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 77685759436.17628

# %% [markdown]
# # 9) Display R2 score

# %%
r2 = r2_score(y_test, ypri)
print("R2 Score:", r2)
# Out:
# R2 Score: -14123426579.175844
